# %%
# %config Completer.use_jedi = False
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
spline = pd.read_csv('build/bspline_output.txt',sep=" ")
ctrlPts = pd.read_csv('build/test.txt',sep=" ",names=['x','y'], header=None)
ax = plt.gca()
spline.plot.scatter(x="x",y="y",ax=ax,c='r')
ctrlPts.plot.scatter(x="x",y="y",ax=ax)
plt.show()
spline.plot(x="x",y="dy")

# %%
spline = pd.read_csv('build/spline_output.txt',sep=" ")
ax = plt.gca()
spline.plot.scatter(x="x",y="y",ax=ax,c='r')
plt.show()
